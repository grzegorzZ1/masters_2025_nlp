# %%
import requests

# %%
ollama_url = f"http://localhost:11434"
prompt = "Hello"

response = requests.post(
    f"{ollama_url}/api/generate",
    json={
        "model": model,
        "prompt": prompt,
        "stream": stream,
    },
    timeout=60,
    stream=False,
)
