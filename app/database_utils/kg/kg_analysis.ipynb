# %%
import os
from rdflib import Graph

INDEX_NAME = os.getenv("INDEX_NAME")

# %%
g = Graph()
g.parse(f"{INDEX_NAME}.ttl", format="turtle")
# Out:
# <Graph identifier=N178c0fe9d2294d6a879b73a3dd011869 (<class 'rdflib.graph.Graph'>)>

# %%
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX ns1: <https://example.com/political-kg/property/> 

SELECT ?s ?p ?o ?creator ?date
WHERE {
    # ?stmt a rdf:Statement ;
          rdf:subject ?s ;
          rdf:predicate ?p ;
          rdf:object ?o ;
          ns1:date ?date .
    FILTER (?date > "1999-01-01"^^xsd:date)
}
"""

for row in g.query(query):
    print(f"{row.s.split('/')[-1]} {row.p.split('/')[-1]} {row.o.split('/')[-1]} | Date: {row.date}")
# Out:
# interior_ministry met_with putin | Date: 2000-01-21
# moscow is_a_criminal_capital_of st_petersburg | Date: 2000-01-21
# moscow worked_closely_with central_election_commission | Date: 2000-01-21
# moscow did_a_lot_to_stop_the_infiltration_of_criminal_elements_into_the_legislative_branch_with tax_police_and_other_law_enforcement_agencies | Date: 2000-01-21
# state holds_back development_of_business,_the_state_and_property | Date: 2000-01-21
# moscow imposes_sanctions_on ukraine | Date: 2000-01-21
# moscow engaged_in_counter-terrorist_operation chechnya | Date: 2000-01-21
# interior_bodies turned_down a_citizen’s_request | Date: 2000-01-21
# duma must_encourage_to_pass federal_laws | Date: 2000-01-21
# duma must_pass laws_on_the_fight_against_graft | Date: 2000-01-21
# duma must_pass laws | Date: 2000-01-21
# duma must_pass laws_on_the_fight_against_organised_crime | Date: 2000-01-21
# country poses_a_danger_to every_person_and_the_country_as_a_whole | Date: 2000-01-21
# ...

# %%
query = """
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX ns1: <https://example.com/political-kg/property/> 
SELECT ?s ?o
WHERE {
    # ?s ns1:embedding ?o .
}
"""
counter = 0
for row in g.query(query):
    print(row.s.split('/')[-2], row.s.split('/')[-1])
    counter += 1
print(f"Total statements: {counter}")
# Out:
# entity 'the_good_tsar_and_the_negligent_officials'
# entity 12%_of_the_gross_domestic_product
# entity 1917
# entity 1998
# entity 1999
# entity 52%
# entity 6,000_servicemen
# entity 67%_oil_refining_depth
# entity [the_leader_of_the_yabloko_bloc]
# entity a_change_that_concerns_situations_when_deputies_commit_a_crime
# entity a_citizen’s_request
# entity a_fund_or_some_kind_of_institution
# entity a_fundamentally_new_stage_with_democratic_principles,_professionalism_and_political_balance.
# entity a_grave_mistake
# entity a_hot_line
# entity a_legislation_of_a_new_century
# entity a_main_task
# entity a_target_of_such_experiments_ever_again
# entity a_very_ambitious_project
# entity advisory_council
# entity all_border_guards
# entity all_of_our_listeners
# entity all_resources_of_the_state,_all_potential_of_society,_and_efforts_of_all_russian_people
# entity an_operation_in_former_yugoslavia
# entity and_creates_an_investment-friendly_climate
# ...
