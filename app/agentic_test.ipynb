# %%
from research_chatbot.graph import ResearchChatbot

# %%
graph = ResearchChatbot().compiled_graph
thread_id = "test_thread_123"

# %%
from IPython.display import Image
Image(graph.get_graph().draw_mermaid_png())

# %%
M = "What questions I asked?"

# %%
agent.work(M, thread_id=thread_id)
# Out:
# 'You asked me what "cat" and "dog" referred to, and how I would typically answer those questions.\n\nFor "cat", I provided three possible meanings, but if I had to choose a context, it would be the domesticated small mammal of the family Felidae.\n\nFor "dog", you correctly pointed out that I didn\'t specify a context, so you assumed I was referring to the domesticated animal. If you\'d like more information on dog behavior, training, or health, I\'d be happy to provide some general knowledge!'

# %%
config = {
    "configurable": {
        "thread_id": thread_id
    }
}

history = agent.compiled_graph.get_state_history(config)
for step in history:
    print(step[0])
# Out:
# {'messages': [HumanMessage(content='What is cat', additional_kwargs={}, response_metadata={}, id='34e89064-4ab7-401d-97f9-38669ea08985'), AIMessage(content='A very broad question! "Cat" can refer to several things:\n\n1. A domesticated small mammal of the family Felidae, often kept as a pet.\n2. A type of navigation system used in wireless networks and other communication systems (e.g., Wi-Fi routers).\n3. An acronym for Computer-Aided Translation, a method for automating translation processes.\n\nWhich context were you thinking of?', additional_kwargs={}, response_metadata={}, id='b0bd7315-5f2e-43a1-8d83-6f193e698e9e', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is dog', additional_kwargs={}, response_metadata={}, id='fe400423-5357-453d-8148-36a2d227df34'), AIMessage(content='A new question!\n\nAgain, "dog" is a very broad term that can refer to:\n\n1. A domesticated carnivorous mammal of the family Canidae, often kept as a pet.\n2. A type of navigation system used in satellite and wireless communication systems (e.g., GPS).\n3. An acronym for Distributed Object Grouping, a concept in distributed computing.\n\nUnless you specify which context you\'re interested in, I\'ll assume you\'re asking about the domesticated animal. Would you like more information on that?', additional_kwargs={}, response_metadata={}, id='b83671d4-4917-4d76-927e-2b0c4b581051', tool_calls=[], invalid_tool_calls=[])], 'response': 'A new question!\n\nAgain, "dog" is a very broad term that can refer to:\n\n1. A domesticated carnivorous mammal of the family Canidae, often kept as a pet.\n2. A type of navigation system used in satellite and wireless communication systems (e.g., GPS).\n3. An acronym for Distributed Object Grouping, a concept in distributed computing.\n\nUnless you specify which context you\'re interested in, I\'ll assume you\'re asking about the domesticated animal. Would you like more information on that?'}
# {'messages': [HumanMessage(content='What is cat', additional_kwargs={}, response_metadata={}, id='34e89064-4ab7-401d-97f9-38669ea08985'), AIMessage(content='A very broad question! "Cat" can refer to several things:\n\n1. A domesticated small mammal of the family Felidae, often kept as a pet.\n2. A type of navigation system used in wireless networks and other communication systems (e.g., Wi-Fi routers).\n3. An acronym for Computer-Aided Translation, a method for automating translation processes.\n\nWhich context were you thinking of?', additional_kwargs={}, response_metadata={}, id='b0bd7315-5f2e-43a1-8d83-6f193e698e9e', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is dog', additional_kwargs={}, response_metadata={}, id='fe400423-5357-453d-8148-36a2d227df34')], 'response': ''}
# {'messages': [HumanMessage(content='What is cat', additional_kwargs={}, response_metadata={}, id='34e89064-4ab7-401d-97f9-38669ea08985'), AIMessage(content='A very broad question! "Cat" can refer to several things:\n\n1. A domesticated small mammal of the family Felidae, often kept as a pet.\n2. A type of navigation system used in wireless networks and other communication systems (e.g., Wi-Fi routers).\n3. An acronym for Computer-Aided Translation, a method for automating translation processes.\n\nWhich context were you thinking of?', additional_kwargs={}, response_metadata={}, id='b0bd7315-5f2e-43a1-8d83-6f193e698e9e', tool_calls=[], invalid_tool_calls=[])], 'response': 'A very broad question! "Cat" can refer to several things:\n\n1. A domesticated small mammal of the family Felidae, often kept as a pet.\n2. A type of navigation system used in wireless networks and other communication systems (e.g., Wi-Fi routers).\n3. An acronym for Computer-Aided Translation, a method for automating translation processes.\n\nWhich context were you thinking of?'}
# {'messages': [HumanMessage(content='What is cat', additional_kwargs={}, response_metadata={}, id='34e89064-4ab7-401d-97f9-38669ea08985'), AIMessage(content='A very broad question! "Cat" can refer to several things:\n\n1. A domesticated small mammal of the family Felidae, often kept as a pet.\n2. A type of navigation system used in wireless networks and other communication systems (e.g., Wi-Fi routers).\n3. An acronym for Computer-Aided Translation, a method for automating translation processes.\n\nWhich context were you thinking of?', additional_kwargs={}, response_metadata={}, id='b0bd7315-5f2e-43a1-8d83-6f193e698e9e', tool_calls=[], invalid_tool_calls=[])], 'response': 'A very broad question! "Cat" can refer to several things:\n\n1. A domesticated small mammal of the family Felidae, often kept as a pet.\n2. A type of navigation system used in wireless networks and other communication systems (e.g., Wi-Fi routers).\n3. An acronym for Computer-Aided Translation, a method for automating translation processes.\n\nWhich context were you thinking of?'}
# {'messages': [HumanMessage(content='What is cat', additional_kwargs={}, response_metadata={}, id='34e89064-4ab7-401d-97f9-38669ea08985')], 'response': ''}
# {'messages': []}
